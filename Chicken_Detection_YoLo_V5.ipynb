# %% [markdown]
# <a href="https://colab.research.google.com/github/MoizAhmed2517/Deep_Learning_Projects/blob/main/Chicken_Detection_YoLo_V5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/ultralytics/yolov5
# %cd yolov5
# %pip install -qr requirements.txt

import torch
from IPython.display import Image, clear_output

clear_output()

# %%
# !unzip -q ../dataset.zip -d ../

# %%
# !python train.py --img 640 --batch  16 --epochs 3 --data custom_data.yaml --weights yolov5x.pt --nosave --cache
# Out:
# train: weights=yolov5x.pt, cfg=, data=custom_data.yaml, hyp=data/hyps/hyp.scratch-low.yaml, epochs=3, batch_size=16, imgsz=640, rect=False, resume=False, nosave=True, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=ram, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs/train, name=exp, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: up to date with https://github.com/ultralytics/yolov5 ✅
# YOLOv5 🚀 v7.0-23-g5dc1ce4 Python-3.8.15 torch-1.12.1+cu113 CUDA:0 (Tesla T4, 15110MiB)
#
# ...

# %%
# !python train.py --img 640 --batch  16 --epochs 20 --data custom_data.yaml --weights yolov5x.pt --nosave --cache
# Out:
# train: weights=yolov5x.pt, cfg=, data=custom_data.yaml, hyp=data/hyps/hyp.scratch-low.yaml, epochs=20, batch_size=16, imgsz=640, rect=False, resume=False, nosave=True, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=ram, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs/train, name=exp, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: up to date with https://github.com/ultralytics/yolov5 ✅
# YOLOv5 🚀 v7.0-23-g5dc1ce4 Python-3.8.15 torch-1.12.1+cu113 CUDA:0 (Tesla T4, 15110MiB)
#
# ...

# %%
# !python detect.py --weights runs/train/exp2/weights/last.pt --img 640 --conf 0.25 --source /content/chickenvideo.mkv
# Out:
# Streaming output truncated to the last 5000 lines.
# video 1/1 (2435/7433) /content/chickenvideo.mkv: 384x640 (no detections), 36.1ms
# video 1/1 (2436/7433) /content/chickenvideo.mkv: 384x640 (no detections), 37.9ms
# video 1/1 (2437/7433) /content/chickenvideo.mkv: 384x640 (no detections), 35.7ms
# video 1/1 (2438/7433) /content/chickenvideo.mkv: 384x640 (no detections), 36.0ms
# video 1/1 (2439/7433) /content/chickenvideo.mkv: 384x640 (no detections), 37.6ms
# video 1/1 (2440/7433) /content/chickenvideo.mkv: 384x640 (no detections), 35.6ms
# video 1/1 (2441/7433) /content/chickenvideo.mkv: 384x640 (no detections), 35.7ms
# video 1/1 (2442/7433) /content/chickenvideo.mkv: 384x640 (no detections), 37.1ms
# video 1/1 (2443/7433) /content/chickenvideo.mkv: 384x640 (no detections), 36.0ms
# video 1/1 (2444/7433) /content/chickenvideo.mkv: 384x640 (no detections), 36.7ms
# video 1/1 (2445/7433) /content/chickenvideo.mkv: 384x640 (no detections), 38.3ms
# ...

# %%
# !python train.py --img 640 --batch  16 --epochs 60 --data custom_data.yaml --weights yolov5x.pt --nosave --cache
# Out:
# train: weights=yolov5x.pt, cfg=, data=custom_data.yaml, hyp=data/hyps/hyp.scratch-low.yaml, epochs=60, batch_size=16, imgsz=640, rect=False, resume=False, nosave=True, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=ram, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs/train, name=exp, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: up to date with https://github.com/ultralytics/yolov5 ✅
# YOLOv5 🚀 v7.0-23-g5dc1ce4 Python-3.8.15 torch-1.12.1+cu113 CUDA:0 (Tesla T4, 15110MiB)
#
# ...

# %%
# !python detect.py --weights runs/train/exp3/weights/best.pt --img 640 --conf 0.25 --source /content/chickenvideo.mkv
# Out:
# Streaming output truncated to the last 5000 lines.
# video 1/1 (2435/7433) /content/chickenvideo.mkv: 384x640 1 chicken, 38.5ms
# video 1/1 (2436/7433) /content/chickenvideo.mkv: 384x640 1 chicken, 35.1ms
# video 1/1 (2437/7433) /content/chickenvideo.mkv: 384x640 1 chicken, 36.2ms
# video 1/1 (2438/7433) /content/chickenvideo.mkv: 384x640 1 chicken, 35.7ms
# video 1/1 (2439/7433) /content/chickenvideo.mkv: 384x640 1 chicken, 35.9ms
# video 1/1 (2440/7433) /content/chickenvideo.mkv: 384x640 1 chicken, 35.1ms
# video 1/1 (2441/7433) /content/chickenvideo.mkv: 384x640 1 chicken, 36.3ms
# video 1/1 (2442/7433) /content/chickenvideo.mkv: 384x640 1 chicken, 36.0ms
# video 1/1 (2443/7433) /content/chickenvideo.mkv: 384x640 1 chicken, 35.6ms
# video 1/1 (2444/7433) /content/chickenvideo.mkv: 384x640 1 chicken, 37.1ms
# video 1/1 (2445/7433) /content/chickenvideo.mkv: 384x640 2 chickens, 35.8ms
# video 1/1 (2446/7433) /content/chickenvideo.mkv: 384x640 2 chickens, 35.6ms
# ...
